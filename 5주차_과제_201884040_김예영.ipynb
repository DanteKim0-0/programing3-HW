# %%
import pandas as pd
import numpy as np

# %%
fueleco = pd.read_csv('prog3/data/vehicles.csv.zip')
fueleco
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 43413  14.982273         0.0        0.0        0.0      19      0.0        0
# 43414  14.330870         0.0        0.0        0.0      20      0.0        0
# ...

# %%
fueleco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43418 entries, 0 to 43417
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        43418 non-null  float64
#  1   barrelsA08       43418 non-null  float64
#  2   charge120        43418 non-null  float64
#  3   charge240        43418 non-null  float64
#  4   city08           43418 non-null  int64
#  5   city08U          43418 non-null  float64
#  6   cityA08          43418 non-null  int64
#  7   cityA08U         43418 non-null  float64
#  8   cityCD           43418 non-null  float64
#  9   cityE            43418 non-null  float64
#  10  cityUF           43418 non-null  float64
#  11  co2              43418 non-null  int64
#  12  co2A             43418 non-null  int64
#  13  co2TailpipeAGpm  43418 non-null  float64
#  14  co2TailpipeGpm   43418 non-null  float64
#  15  comb08           43418 non-null  int64
# ...

# %%
fueleco.mpgData.value_counts()
# Out:
# N    29726
# Y    13674
# Name: mpgData, dtype: int64

# %%
fueleco.VClass.value_counts()
# Out:
# Compact Cars                          6086
# Subcompact Cars                       5381
# Midsize Cars                          5184
# Large Cars                            2359
# Standard Pickup Trucks                2354
# Two Seaters                           2215
# Sport Utility Vehicle - 4WD           2078
# Small Station Wagons                  1662
# Sport Utility Vehicle - 2WD           1627
# Special Purpose Vehicles              1455
# Minicompact Cars                      1452
# Standard Pickup Trucks 2WD            1333
# Standard Pickup Trucks 4WD            1190
# Small Sport Utility Vehicle 4WD       1152
# Vans                                  1141
# Standard Sport Utility Vehicle 4WD     911
# Small Sport Utility Vehicle 2WD        759
# Special Purpose Vehicle 2WD            698
# Midsize-Large Station Wagons           656
# Midsize Station Wagons                 566
# Small Pickup Trucks                    538
# Small Pickup Trucks 2WD                485
# ...

# %%
fueleco.model.value_counts()
# Out:
# F150 Pickup 2WD             226
# F150 Pickup 4WD             205
# Mustang                     201
# Camaro                      198
# Jetta                       196
#                            ...
# Pathfinder Armada 4WD         1
# Pathfinder Armada 2WD         1
# M4 DTM Champions Edition      1
# E500 (Wagon)                  1
# XJRS Coupe                    1
# Name: model, Length: 4375, dtype: int64

# %%
fueleco.eng_dscr.value_counts()
# Out:
# (FFS)                           8827
# SIDI                            6828
# (FFS) CA model                   926
# (FFS)      (MPFI)                734
# FFV                              703
#                                 ...
# FFV; Cargo Van                     1
# RNG=190                            1
# Shelby GT500; Coupe or Conv.       1
# RNG=250                            1
# MAZDA3 T/C                         1
# Name: eng_dscr, Length: 562, dtype: int64

# %%
fueleco.model.isna().sum()
# Out:
# 0

# %%
fueleco.VClass.isna().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 18))
plt.bar(fueleco.VClass.value_counts().index, fueleco.VClass.value_counts())
# Out:
# <BarContainer object of 34 artists>

# %%
import seaborn as sns
sns.barplot(fueleco.VClass.value_counts().index, fueleco.VClass.value_counts())
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='VClass'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.countplot(y='model', data=(fueleco), order=fueleco.model.value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='model'>

# %%
top_n = fueleco.model.value_counts().index[:6]
top_n
# Out:
# Index(['F150 Pickup 2WD', 'F150 Pickup 4WD', 'Mustang', 'Camaro', 'Jetta',
#        'Truck 2WD'],
#       dtype='object')

# %%
fueleco.model.where(fueleco.model.isin(top_n), 'Other').value_counts()
# Out:
# Other              42205
# F150 Pickup 2WD      226
# F150 Pickup 4WD      205
# Mustang              201
# Camaro               198
# Jetta                196
# Truck 2WD            187
# Name: model, dtype: int64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,8))
top_n = fueleco.model.value_counts().index[:6]
(
    fueleco.assign(
        make=fueleco.model.where(
            fueleco.model.isin(top_n), 'Other'))
    .model.value_counts()[1:]
    .plot.bar(ax=ax)
    
)
# Out:
# <AxesSubplot:>

# %%
fueleco.fuelType1.value_counts()
# Out:
# Regular Gasoline     28828
# Premium Gasoline     12921
# Diesel                1203
# Electricity            276
# Midgrade Gasoline      130
# Natural Gas             60
# Name: fuelType1, dtype: int64

# %%
fueleco.model.value_counts().head()
# Out:
# F150 Pickup 2WD    226
# F150 Pickup 4WD    205
# Mustang            201
# Camaro             198
# Jetta              196
# Name: model, dtype: int64

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10,8))
top_n = fueleco.model.value_counts().index[:6]
sns.countplot(y='model',
              data=(fueleco[fueleco.model.isin(top_n)])
              , hue='fuelType1', order=fueleco.model.value_counts().index[:6]
              #, dodge=False
             )
# Out:
# <AxesSubplot:xlabel='count', ylabel='model'>

# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
mask
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_1708/56715091.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
# array([[ True,  True,  True,  True,  True,  True],
#        [False,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True],
#        [False, False, False, False,  True,  True],
#        [False, False, False, False, False,  True]])

# %%
fig, ax = plt.subplots(figsize=(8,8))
corr = fueleco[['year', 'fuelCost08', 'youSaveSpend', 'range', 'barrels08', 'charge120']].corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(
    corr,
    mask=mask,
    fmt='.2f',
    annot=True,
    ax=ax,
    cmap='RdBu',
    vmin=-1,
    vmax=1,
    square=True
)
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_1708/1900593095.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
# <AxesSubplot:>
